# %% [markdown]
# # Data Preparation
# #### In this notebook we will prepare the data for our search function. <br> The data is stored in 3 different ```.xlsx``` file.<br>
# * Apps.xlsx
# * App_Specs.xlsx
# * App_Ratings.xlsx
#
# Since analysing from multiple sources will not be an efficient way, so we have to prepare our data in an easily searchable structure

# %%
#Import the required modules
import pandas as pd
from os import getcwd
from collections import defaultdict

# %% [markdown]
# ### Define the paths

# %%
path_apps = f"{getcwd()}/Datastore/Apps.xlsx"
path_specs = f"{getcwd()}/Datastore/App_Specs.xlsx"
path_rating = f"{getcwd()}/Datastore/App_Ratings.xlsx"

# %% [markdown]
# ## Data Engineering
# 1. Getting data into dataframes
# 2. Convert data to a Single Dictionary

# %%
"""
    Read data from Apps.xlsx 
"""
df_apps = pd.read_excel(path_apps)
apps_table_columns = df_apps.columns.tolist()
print(f"Columns are : {apps_table_columns}")
# Out:
# Columns are : ['App_id', 'Title', 'Genre']

# %%
"""
    Read data from App_Specs.xlsx 
"""
df_specs = pd.read_excel(path_specs)
specs_table_columns = df_specs.columns.tolist()
print(f"Columns are : {specs_table_columns}")
# Out:
# Columns are : ['App_id', 'Type', 'Size', 'Android', 'Current Version']

# %%
"""
    Read data from App_Ratings.xlsx
"""
df_ratings = pd.read_excel(path_rating)
ratings_table_columns = df_ratings.columns.tolist()
print(f"COLUMNS : {ratings_table_columns}")
# Out:
# COLUMNS : ['App_id', 'Rating', 'Reviews', 'Downloads']

# %% [markdown]
# Primary Search Key - ```App_id``` since it is a common attribute in all the dataframes.
#
# A user will always search an application by its ```title``` so we will create a Global secondary index
# to be able to perform search operation on our datastore.

# %% [markdown]
# ##  Check Primary Search Key's Property (Unique/Redundant)

# %%
print(f"It is {pd.Series(df_apps['App_id']).is_unique}  that the column 'App_id' has unique values for all entries in Apps dataframe.")
print(f"It is {pd.Series(df_specs['App_id']).is_unique}  that the column 'App_id' has unique values for all entries in Specs dataframe.")
print(f"It is {pd.Series(df_ratings['App_id']).is_unique} that the column 'App_id' has unique values for all entries in Ratings dataframe.")
# Out:
# It is True  that the column 'App_id' has unique values for all entries in Apps dataframe.
# It is True  that the column 'App_id' has unique values for all entries in Specs dataframe.
# It is True that the column 'App_id' has unique values for all entries in Ratings dataframe.

# %% [markdown]
# ## Sort the Dataframes

# %%
#Apps Dataframe
df_apps_sorted = df_apps.sort_values(by = ['App_id'])

#Specs Dataframe
df_specs_sorted = df_specs.sort_values(by = ['App_id'])

#Ratings Dataframe
df_ratings_sorted = df_ratings.sort_values(by = ['App_id'])

# %% [markdown]
# All the dataframes have been sorted with respect to ```App_id```, since it is a unique key.

# %%
#From Apps Dataframe
App_id = df_apps["App_id"].tolist()
App_Title = df_apps["Title"].tolist()
App_Genre = df_apps["Genre"].tolist()

#From Specs Dataframe
App_Type = df_specs["Type"].tolist()
App_Size = df_specs["Size"].tolist()
App_Android = df_specs["Android"].tolist()
App_Current = df_specs["Current Version"].tolist()

#From Ratings Dataframe
App_Rating = df_ratings["Rating"].tolist()
App_Reviews = df_ratings["Reviews"].tolist()
App_Downloads = df_ratings["Downloads"].tolist()

# %%
#Making a Single Dictionary for all the Columns
appDict = {}
global_secondaryIndex = {}
for idx, Id in enumerate(App_id) : 
    appDict[Id] = {
        "Title" : App_Title[idx],
        "Genre" : App_Genre[idx],
        "Type" : App_Type[idx],
        "Size" : App_Size[idx],
        "Android Version" : App_Android[idx],
        "Current Version" : App_Current[idx],
        "Average Rating" : App_Rating[idx],
        "Reviews" : App_Reviews[idx],
        "Downloads" : App_Downloads[idx]
    }
    global_secondaryIndex[App_Title[idx]] = Id

appDict
# Out:
# {1: {'Title': 'Photo Editor & Candy Camera & Grid & ScrapBook',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '19 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '1.0.0',
#   'Average Rating': 4.1,
#   'Reviews': 159,
#   'Downloads': '10,000+'},
#  2: {'Title': 'Coloring book moana',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '14 MB',
#   'Android Version': '2.0.0',
#   'Current Version': 'January 15, 2018',
#   'Average Rating': 3.9,
#   'Reviews': 967,
#   'Downloads': '500,000+'},
#  3: {'Title': 'U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '8.7 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '1.2.4',
#   'Average Rating': 4.7,
#   'Reviews': 87510,
#   'Downloads': '5,000,000+'},
#  4: {'Title': 'Sketch - Draw & Paint',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '25 MB',
#   'Android Version': '4.2 and up',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.5,
#   'Reviews': 215644,
#   'Downloads': '50,000,000+'},
#  5: {'Title': 'Pixel Draw - Number Art Coloring Book',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '2.8 MB',
#   'Android Version': 1.1,
#   'Current Version': 'June 20, 2018',
#   'Average Rating': 4.3,
#   'Reviews': 967,
#   'Downloads': '100,000+'},
#  6: {'Title': 'Paper flowers instructions',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '5.6 MB',
#   'Android Version': '2.3 and up',
#   'Current Version': 1,
#   'Average Rating': 4.4,
#   'Reviews': 167,
#   'Downloads': '50,000+'},
#  7: {'Title': 'Smoke Effect Photo Maker - Smoke Editor',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '19 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 1.1,
#   'Average Rating': 3.8,
#   'Reviews': 178,
#   'Downloads': '50,000+'},
#  8: {'Title': 'Infinite Painter',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '29 MB',
#   'Android Version': '4.2 and up',
#   'Current Version': '6.1.61.1',
#   'Average Rating': 4.1,
#   'Reviews': 36815,
#   'Downloads': '1,000,000+'},
#  9: {'Title': 'Garden Coloring Book',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '33 MB',
#   'Android Version': '3.0 and up',
#   'Current Version': '2.9.2',
#   'Average Rating': 4.4,
#   'Reviews': 13791,
#   'Downloads': '1,000,000+'},
#  10: {'Title': 'Kids Paint Free - Drawing Fun',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '3.1 MB',
#   'Android Version': 2.8,
#   'Current Version': 'July 3, 2018',
#   'Average Rating': 4.7,
#   'Reviews': 121,
#   'Downloads': '10,000+'},
#  11: {'Title': 'Text on Photo - Fonteee',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '28 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '1.0.4',
#   'Average Rating': 4.4,
#   'Reviews': 13880,
#   'Downloads': '1,000,000+'},
#  12: {'Title': 'Name Art Photo Editor - Focus n Filters',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '12 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': '1.0.15',
#   'Average Rating': 4.4,
#   'Reviews': 8788,
#   'Downloads': '1,000,000+'},
#  13: {'Title': 'Tattoo Name On My Photo Editor',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '20 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 3.8,
#   'Average Rating': 4.2,
#   'Reviews': 44829,
#   'Downloads': '10,000,000+'},
#  14: {'Title': 'Mandala Coloring Book',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '21 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '1.0.4',
#   'Average Rating': 4.6,
#   'Reviews': 4326,
#   'Downloads': '100,000+'},
#  15: {'Title': '3D Color Pixel by Number - Sandbox Art Coloring',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '37 MB',
#   'Android Version': '2.3 and up',
#   'Current Version': '1.2.3',
#   'Average Rating': 4.4,
#   'Reviews': 1518,
#   'Downloads': '100,000+'},
#  16: {'Title': 'Learn To Draw Kawaii Characters',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '2.7 MB',
#   'Android Version': '4.2 and up',
#   'Current Version': nan,
#   'Average Rating': 3.2,
#   'Reviews': 55,
#   'Downloads': '5,000+'},
#  17: {'Title': 'Photo Designer - Write your name with shapes',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '5.5 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 3.1,
#   'Average Rating': 4.7,
#   'Reviews': 3632,
#   'Downloads': '500,000+'},
#  18: {'Title': '350 Diy Room Decor Ideas',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '17 MB',
#   'Android Version': '2.3 and up',
#   'Current Version': 1,
#   'Average Rating': 4.5,
#   'Reviews': 27,
#   'Downloads': '10,000+'},
#  19: {'Title': 'FlipaClip - Cartoon animation',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '39 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '2.2.5',
#   'Average Rating': 4.3,
#   'Reviews': 194216,
#   'Downloads': '5,000,000+'},
#  20: {'Title': 'ibis Paint X',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '31 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '5.5.4',
#   'Average Rating': 4.6,
#   'Reviews': 224399,
#   'Downloads': '10,000,000+'},
#  21: {'Title': 'Logo Maker - Small Business',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '14 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 4,
#   'Average Rating': 4.0,
#   'Reviews': 450,
#   'Downloads': '100,000+'},
#  22: {'Title': "Boys Photo Editor - Six Pack & Men's Suit",
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '12 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 1.1,
#   'Average Rating': 4.1,
#   'Reviews': 654,
#   'Downloads': '100,000+'},
#  23: {'Title': 'Superheroes Wallpapers | 4K Backgrounds',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '4.2 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '2.2.6.2',
#   'Average Rating': 4.7,
#   'Reviews': 7699,
#   'Downloads': '500,000+'},
#  24: {'Title': 'Mcqueen Coloring pages',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '7.0 MB',
#   'Android Version': '1.0.0',
#   'Current Version': 'March 7, 2018',
#   'Average Rating': nan,
#   'Reviews': 61,
#   'Downloads': '100,000+'},
#  25: {'Title': 'HD Mickey Minnie Wallpapers',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '23 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '1.1.3',
#   'Average Rating': 4.7,
#   'Reviews': 118,
#   'Downloads': '50,000+'},
#  26: {'Title': 'Harley Quinn wallpapers HD',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '6.0 MB',
#   'Android Version': '3.0 and up',
#   'Current Version': 1.5,
#   'Average Rating': 4.8,
#   'Reviews': 192,
#   'Downloads': '10,000+'},
#  27: {'Title': 'Colorfit - Drawing & Coloring',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '25 MB',
#   'Android Version': '1.0.8',
#   'Current Version': 'October 11, 2017',
#   'Average Rating': 4.7,
#   'Reviews': 20260,
#   'Downloads': '500,000+'},
#  28: {'Title': 'Animated Photo Editor',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '6.1 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 1.03,
#   'Average Rating': 4.1,
#   'Reviews': 203,
#   'Downloads': '100,000+'},
#  29: {'Title': 'Pencil Sketch Drawing',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '4.6 MB',
#   'Android Version': '2.3 and up',
#   'Current Version': 6,
#   'Average Rating': 3.9,
#   'Reviews': 136,
#   'Downloads': '10,000+'},
#  30: {'Title': 'Easy Realistic Drawing Tutorial',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '4.2 MB',
#   'Android Version': '2.3 and up',
#   'Current Version': 1,
#   'Average Rating': 4.1,
#   'Reviews': 223,
#   'Downloads': '100,000+'},
#  31: {'Title': 'Pink Silver Bow Keyboard Theme',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '9.2 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '6.7.12.2018',
#   'Average Rating': 4.2,
#   'Reviews': 1120,
#   'Downloads': '100,000+'},
#  32: {'Title': 'Art Drawing Ideas',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '5.2 MB',
#   'Android Version': '2.3 and up',
#   'Current Version': 1.2,
#   'Average Rating': 4.1,
#   'Reviews': 227,
#   'Downloads': '50,000+'},
#  33: {'Title': 'Anime Manga Coloring Book',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '11 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': 2.2,
#   'Average Rating': 4.5,
#   'Reviews': 5035,
#   'Downloads': '100,000+'},
#  34: {'Title': 'Easy Origami Ideas',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '11 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '1.1.0',
#   'Average Rating': 4.2,
#   'Reviews': 1015,
#   'Downloads': '100,000+'},
#  35: {'Title': 'I Creative Idea',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '4.2 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 1.6,
#   'Average Rating': 4.7,
#   'Reviews': 353,
#   'Downloads': '10,000+'},
#  36: {'Title': 'How to draw Ladybug and Cat Noir',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '9.2 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 2.1,
#   'Average Rating': 3.8,
#   'Reviews': 564,
#   'Downloads': '100,000+'},
#  37: {'Title': 'UNICORN - Color By Number & Pixel Art Coloring',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '24 MB',
#   'Android Version': '1.0.9',
#   'Current Version': 'August 2, 2018',
#   'Average Rating': 4.7,
#   'Reviews': 8145,
#   'Downloads': '500,000+'},
#  38: {'Title': 'Floor Plan Creator',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': '2.3.3 and up',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.1,
#   'Reviews': 36639,
#   'Downloads': '5,000,000+'},
#  39: {'Title': 'PIP Camera - PIP Collage Maker',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '11 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 1.3,
#   'Average Rating': 4.7,
#   'Reviews': 158,
#   'Downloads': '10,000+'},
#  40: {'Title': 'How To Color Disney Princess - Coloring Pages',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '9.4 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': 1,
#   'Average Rating': 4.0,
#   'Reviews': 591,
#   'Downloads': '500,000+'},
#  41: {'Title': 'Drawing Clothes Fashion Ideas',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '15 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '2.0.1',
#   'Average Rating': 4.2,
#   'Reviews': 117,
#   'Downloads': '10,000+'},
#  42: {'Title': 'Sad Poetry Photo Frames 2018',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '10 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 1,
#   'Average Rating': 4.5,
#   'Reviews': 176,
#   'Downloads': '100,000+'},
#  43: {'Title': 'Textgram - write on photos',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.4,
#   'Reviews': 295221,
#   'Downloads': '10,000,000+'},
#  44: {'Title': 'Paint Splash!',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '1.2 MB',
#   'Android Version': 1.46,
#   'Current Version': 'April 15, 2018',
#   'Average Rating': 3.8,
#   'Reviews': 2206,
#   'Downloads': '100,000+'},
#  45: {'Title': 'Popsicle Sticks and Similar DIY Craft Ideas',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '12 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '1.0.0',
#   'Average Rating': 4.2,
#   'Reviews': 26,
#   'Downloads': '10,000+'},
#  46: {'Title': 'Canva: Poster, banner, card maker & graphic design',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '24 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '1.6.1',
#   'Average Rating': 4.7,
#   'Reviews': 174531,
#   'Downloads': '10,000,000+'},
#  47: {'Title': 'Install images with music to make video without Net - 2018',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '26 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 1.6,
#   'Average Rating': 4.6,
#   'Reviews': 1070,
#   'Downloads': '100,000+'},
#  48: {'Title': 'Little Teddy Bear Colouring Book Game',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '8.0 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '2.0.0',
#   'Average Rating': 4.2,
#   'Reviews': 85,
#   'Downloads': '100,000+'},
#  49: {'Title': 'How To Draw Food',
#   'Genre': 'ART_AND_DESIGN',
#   'Type': 'Free',
#   'Size': '7.9 MB',
#   'Android Version': '2.3 and up',
#   'Current Version': 1,
#   'Average Rating': 4.3,
#   'Reviews': 845,
#   'Downloads': '100,000+'},
#  50: {'Title': 'Monster Truck Stunt 3D 2019',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '25 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 1,
#   'Average Rating': 4.2,
#   'Reviews': 367,
#   'Downloads': '100,000+'},
#  51: {'Title': 'Real Tractor Farming',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '56 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 11,
#   'Average Rating': 4.0,
#   'Reviews': 1598,
#   'Downloads': '1,000,000+'},
#  52: {'Title': 'Ultimate F1 Racing Championship',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '57 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 3,
#   'Average Rating': 3.8,
#   'Reviews': 284,
#   'Downloads': '100,000+'},
#  53: {'Title': 'Used Cars and Trucks for Sale',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.6,
#   'Reviews': 17057,
#   'Downloads': '1,000,000+'},
#  54: {'Title': 'American Muscle Car Race',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '35 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 3,
#   'Average Rating': 3.9,
#   'Reviews': 129,
#   'Downloads': '100,000+'},
#  55: {'Title': 'Offroad Oil Tanker Driver Transport Truck 2019',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '33 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 4,
#   'Average Rating': 4.3,
#   'Reviews': 542,
#   'Downloads': '100,000+'},
#  56: {'Title': 'Tickets SDA 2018 and Exam from the State Traffic Safety Inspectorate with Drom.ru',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '33 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': '1.7.1',
#   'Average Rating': 4.9,
#   'Reviews': 10479,
#   'Downloads': '100,000+'},
#  57: {'Title': 'Gas Prices (Germany only)',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '5.6 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '2.5.1',
#   'Average Rating': 4.4,
#   'Reviews': 805,
#   'Downloads': '50,000+'},
#  58: {'Title': 'Extreme Rally Championship',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '54 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 3,
#   'Average Rating': 4.2,
#   'Reviews': 129,
#   'Downloads': '100,000+'},
#  59: {'Title': 'Restart Navigator',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '201k',
#   'Android Version': '2.2 and up',
#   'Current Version': '1.0.1',
#   'Average Rating': 4.0,
#   'Reviews': 1403,
#   'Downloads': '100,000+'},
#  60: {'Title': 'REG - Check the regnumber, find information about Swedish vehicles',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '3.6 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': 2.493,
#   'Average Rating': 3.9,
#   'Reviews': 3971,
#   'Downloads': '100,000+'},
#  61: {'Title': 'CityBus Lviv',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '5.7 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '1.9.1',
#   'Average Rating': 4.6,
#   'Reviews': 534,
#   'Downloads': '10,000+'},
#  62: {'Title': 'CDL Practice Test 2018 Edition',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '17 MB',
#   'Android Version': '4.2 and up',
#   'Current Version': 1.7,
#   'Average Rating': 4.9,
#   'Reviews': 7774,
#   'Downloads': '100,000+'},
#  63: {'Title': 'ezETC (ETC balance inquiry, meter trial, real-time traffic)',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '8.6 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '2.20 Build 02',
#   'Average Rating': 4.3,
#   'Reviews': 38846,
#   'Downloads': '1,000,000+'},
#  64: {'Title': 'Free VIN Report for Used Cars',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '2.4 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': 1.37,
#   'Average Rating': 4.6,
#   'Reviews': 2431,
#   'Downloads': '100,000+'},
#  65: {'Title': 'DMV Permit Practice Test 2018 Edition',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '27 MB',
#   'Android Version': '4.2 and up',
#   'Current Version': 1.7,
#   'Average Rating': 4.9,
#   'Reviews': 6090,
#   'Downloads': '100,000+'},
#  66: {'Title': 'Check Vehicle Tax',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '2.7 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '0.2.1',
#   'Average Rating': 3.9,
#   'Reviews': 295,
#   'Downloads': '10,000+'},
#  67: {'Title': 'Used Cars Mexico',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '2.5 MB',
#   'Android Version': '2.3 and up',
#   'Current Version': 1,
#   'Average Rating': 4.0,
#   'Reviews': 190,
#   'Downloads': '50,000+'},
#  68: {'Title': 'Ulysse Speedometer',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.3,
#   'Reviews': 40211,
#   'Downloads': '5,000,000+'},
#  69: {'Title': 'REPUVE',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 3.9,
#   'Reviews': 356,
#   'Downloads': '100,000+'},
#  70: {'Title': 'Used cars for sale - Trovit',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '7.0 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '4.47.3',
#   'Average Rating': 4.2,
#   'Reviews': 52530,
#   'Downloads': '5,000,000+'},
#  71: {'Title': 'Fines of the State Traffic Safety Inspectorate are official: inspection, payment of fines',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '35 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '1.9.7',
#   'Average Rating': 4.8,
#   'Reviews': 116986,
#   'Downloads': '5,000,000+'},
#  72: {'Title': 'SK Enca Direct Malls - Used Cars Search',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '16 MB',
#   'Android Version': '4.2 and up',
#   'Current Version': '2.2.21',
#   'Average Rating': 3.6,
#   'Reviews': 1379,
#   'Downloads': '500,000+'},
#  73: {'Title': 'Android Auto - Maps, Media, Messaging & Voice',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '16 MB',
#   'Android Version': '5.0 and up',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.2,
#   'Reviews': 271920,
#   'Downloads': '10,000,000+'},
#  74: {'Title': 'PDD-UA',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': '2.3.3 and up',
#   'Current Version': 2.9,
#   'Average Rating': 4.8,
#   'Reviews': 736,
#   'Downloads': '100,000+'},
#  75: {'Title': 'Tickets SDA 2019 + Exam RF',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '17 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': 1.79,
#   'Average Rating': 4.8,
#   'Reviews': 7021,
#   'Downloads': '500,000+'},
#  76: {'Title': 'Super Cars Wallpapers And Backgrounds',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '3.4 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': 1.3,
#   'Average Rating': 4.6,
#   'Reviews': 197,
#   'Downloads': '50,000+'},
#  77: {'Title': 'Police Lights, Sirens & Follow Me',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '8.9 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '2.3.5.1',
#   'Average Rating': 4.5,
#   'Reviews': 737,
#   'Downloads': '100,000+'},
#  78: {'Title': 'Police Detector (Speed Camera Radar)',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '3.9 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': 1.6,
#   'Average Rating': 4.3,
#   'Reviews': 3574,
#   'Downloads': '1,000,000+'},
#  79: {'Title': 'Best Car Wallpapers',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '2.9 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 1.6,
#   'Average Rating': 4.5,
#   'Reviews': 994,
#   'Downloads': '100,000+'},
#  80: {'Title': 'Tickets + PDA 2018 Exam',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '38 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 8.31,
#   'Average Rating': 4.9,
#   'Reviews': 197136,
#   'Downloads': '1,000,000+'},
#  81: {'Title': 'Pick Your Part Garage',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '32 MB',
#   'Android Version': '6.0 and up',
#   'Current Version': '1.1.5.0',
#   'Average Rating': 3.9,
#   'Reviews': 142,
#   'Downloads': '50,000+'},
#  82: {'Title': 'PakWheels: Buy & Sell Cars',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '37 MB',
#   'Android Version': '4.2 and up',
#   'Current Version': '10.0.2',
#   'Average Rating': 4.4,
#   'Reviews': 15168,
#   'Downloads': '1,000,000+'},
#  83: {'Title': 'Supervision service',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '15 MB',
#   'Android Version': '5.0 and up',
#   'Current Version': '1.10.3',
#   'Average Rating': 4.0,
#   'Reviews': 2155,
#   'Downloads': '500,000+'},
#  84: {'Title': 'Speed Camera Detector - Traffic & Speed Alert',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '5.4 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 1,
#   'Average Rating': 4.3,
#   'Reviews': 138,
#   'Downloads': '100,000+'},
#  85: {'Title': 'Used car search Goo net whole car Go to net',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '18 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '3.20.1',
#   'Average Rating': 3.7,
#   'Reviews': 5414,
#   'Downloads': '1,000,000+'},
#  86: {'Title': 'CarMax – Cars for Sale: Search Used Car Inventory',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.4,
#   'Reviews': 21777,
#   'Downloads': '1,000,000+'},
#  87: {'Title': 'BEST CAR SOUNDS',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '38 MB',
#   'Android Version': '2.3 and up',
#   'Current Version': '1.0.3',
#   'Average Rating': 4.3,
#   'Reviews': 348,
#   'Downloads': '100,000+'},
#  88: {'Title': 'RST - Sale of cars on the PCT',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '1.1 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 1.4,
#   'Average Rating': 3.2,
#   'Reviews': 250,
#   'Downloads': '100,000+'},
#  89: {'Title': 'AutoScout24 Switzerland – Find your new car',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.6,
#   'Reviews': 13372,
#   'Downloads': '1,000,000+'},
#  90: {'Title': 'Zona Azul Digital Fácil SP CET - OFFICIAL São Paulo',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': '4.6.5',
#   'Average Rating': 4.6,
#   'Reviews': 7880,
#   'Downloads': '100,000+'},
#  91: {'Title': 'SMS Park',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '7.9 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '2.8.2',
#   'Average Rating': 4.5,
#   'Reviews': 3617,
#   'Downloads': '100,000+'},
#  92: {'Title': 'SKencar',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '35 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '4.0.3',
#   'Average Rating': 3.7,
#   'Reviews': 4806,
#   'Downloads': '1,000,000+'},
#  93: {'Title': 'Fuelio: Gas log & costs',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.6,
#   'Reviews': 65786,
#   'Downloads': '1,000,000+'},
#  94: {'Title': 'auto fines',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '17 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 1.4,
#   'Average Rating': 4.6,
#   'Reviews': 31433,
#   'Downloads': '1,000,000+'},
#  95: {'Title': 'Used car is the first car - used car purchase, used car quotation, dealer information to',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '19 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '1.5.18',
#   'Average Rating': 4.6,
#   'Reviews': 5097,
#   'Downloads': '1,000,000+'},
#  96: {'Title': 'All of the parking lot - National Park application (parking lot search / parking sharing / discount payment)',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '14 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': '2.3.4',
#   'Average Rating': 4.0,
#   'Reviews': 1754,
#   'Downloads': '500,000+'},
#  97: {'Title': 'Inquiry Fines and Debits of Vehicles',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '2.2 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 1.03,
#   'Average Rating': 4.4,
#   'Reviews': 2680,
#   'Downloads': '500,000+'},
#  98: {'Title': 'Gas Station',
#   'Genre': 'AUTO_AND_VEHICLES',
#   'Type': 'Free',
#   'Size': '4.5 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': 2.17,
#   'Average Rating': 4.0,
#   'Reviews': 1288,
#   'Downloads': '100,000+'},
#  99: {'Title': 'Hush - Beauty for Everyone',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '17 MB',
#   'Android Version': '5.0 and up',
#   'Current Version': '6.10.1',
#   'Average Rating': 4.7,
#   'Reviews': 18900,
#   'Downloads': '500,000+'},
#  100: {'Title': 'ipsy: Makeup, Beauty, and Tips',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '14 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '2.3.0',
#   'Average Rating': 4.9,
#   'Reviews': 49790,
#   'Downloads': '1,000,000+'},
#  101: {'Title': 'Natural recipes for your beauty',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '9.8 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 4,
#   'Average Rating': 4.7,
#   'Reviews': 1150,
#   'Downloads': '100,000+'},
#  102: {'Title': 'BestCam Selfie-selfie, beauty camera, photo editor',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '21 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '1.0.6',
#   'Average Rating': 3.9,
#   'Reviews': 1739,
#   'Downloads': '500,000+'},
#  103: {'Title': 'Mirror - Zoom & Exposure -',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 3.9,
#   'Reviews': 32090,
#   'Downloads': '1,000,000+'},
#  104: {'Title': 'Beauty Selfie Camera',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '52 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 1.6,
#   'Average Rating': 4.2,
#   'Reviews': 2225,
#   'Downloads': '500,000+'},
#  105: {'Title': 'Hairstyles step by step',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '14 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 1.9,
#   'Average Rating': 4.6,
#   'Reviews': 4369,
#   'Downloads': '100,000+'},
#  106: {'Title': 'Filters for Selfie',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '25 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': '1.1.0',
#   'Average Rating': 4.3,
#   'Reviews': 8572,
#   'Downloads': '1,000,000+'},
#  107: {'Title': 'Tie - Always be happy',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '9.0 MB',
#   'Android Version': '4.2 and up',
#   'Current Version': 4,
#   'Average Rating': 4.7,
#   'Reviews': 964,
#   'Downloads': '50,000+'},
#  108: {'Title': 'Ulta Beauty',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': '5.0 and up',
#   'Current Version': 5.4,
#   'Average Rating': 4.7,
#   'Reviews': 42050,
#   'Downloads': '1,000,000+'},
#  109: {'Title': 'Prom MakeUp Tutorial',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '12 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 1.3,
#   'Average Rating': 4.8,
#   'Reviews': 104,
#   'Downloads': '10,000+'},
#  110: {'Title': 'Selfie Camera',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.2,
#   'Reviews': 17934,
#   'Downloads': '1,000,000+'},
#  111: {'Title': 'Sweet Selfie Beauty Camera',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '35 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': '2.0.0',
#   'Average Rating': 4.3,
#   'Reviews': 601,
#   'Downloads': '100,000+'},
#  112: {'Title': 'Colors of white in Urdu',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '6.7 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': 6,
#   'Average Rating': 4.5,
#   'Reviews': 36,
#   'Downloads': '10,000+'},
#  113: {'Title': 'Selfie Camera Photo Editor & Filter & Sticker',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '30 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '3.0.1',
#   'Average Rating': 4.1,
#   'Reviews': 187,
#   'Downloads': '50,000+'},
#  114: {'Title': 'Wrinkles and rejuvenation',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '5.7 MB',
#   'Android Version': '3.0 and up',
#   'Current Version': 8,
#   'Average Rating': nan,
#   'Reviews': 182,
#   'Downloads': '100,000+'},
#  115: {'Title': 'Eyes Makeup Beauty Tips',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '2.9 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '3.3.9',
#   'Average Rating': 4.2,
#   'Reviews': 30,
#   'Downloads': '10,000+'},
#  116: {'Title': 'Photo Editor 2018',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '17 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 1.2,
#   'Average Rating': 4.5,
#   'Reviews': 134,
#   'Downloads': '10,000+'},
#  117: {'Title': 'Step By Step Eyes Makeup Tutorial',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '2.9 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '2.3.09',
#   'Average Rating': 4.4,
#   'Reviews': 74,
#   'Downloads': '10,000+'},
#  118: {'Title': 'Beauty Camera - Selfie Camera',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.0,
#   'Reviews': 113715,
#   'Downloads': '10,000,000+'},
#  119: {'Title': 'Girls Hairstyles',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': '4.0 and up',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.1,
#   'Reviews': 3595,
#   'Downloads': '500,000+'},
#  120: {'Title': 'Mirror Camera (Mirror + Selfie Camera)',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '2.6 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': '1.4.2',
#   'Average Rating': 4.1,
#   'Reviews': 9315,
#   'Downloads': '1,000,000+'},
#  121: {'Title': 'Beauty Tips - Beauty Tips in Sinhala',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '4.2 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '1.0.0',
#   'Average Rating': 4.4,
#   'Reviews': 75,
#   'Downloads': '50,000+'},
#  122: {'Title': 'Haircut Tutorials/Haircut Videos',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '7.1 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': 1,
#   'Average Rating': 4.6,
#   'Reviews': 38,
#   'Downloads': '10,000+'},
#  123: {'Title': 'Sephora: Skin Care, Beauty Makeup & Fragrance Shop',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '57 MB',
#   'Android Version': '5.0 and up',
#   'Current Version': 18.5,
#   'Average Rating': 4.5,
#   'Reviews': 26834,
#   'Downloads': '1,000,000+'},
#  124: {'Title': 'Manicure - nail design',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '3.7 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 1.3,
#   'Average Rating': nan,
#   'Reviews': 119,
#   'Downloads': '50,000+'},
#  125: {'Title': 'Sticker Camera - Selfie Filters, Beauty Camera',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '22 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '1.1.0',
#   'Average Rating': 3.9,
#   'Reviews': 2277,
#   'Downloads': '500,000+'},
#  126: {'Title': 'Filters for B Live',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '24 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': '1.1.0',
#   'Average Rating': 4.4,
#   'Reviews': 2280,
#   'Downloads': '500,000+'},
#  127: {'Title': 'Skin Care and Natural Beauty',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '7.4 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 1.15,
#   'Average Rating': nan,
#   'Reviews': 654,
#   'Downloads': '100,000+'},
#  128: {'Title': 'Facial Wrinkle Reduction',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '21 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 1.5,
#   'Average Rating': 4.6,
#   'Reviews': 184,
#   'Downloads': '10,000+'},
#  129: {'Title': 'Makeup Videos',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '3.4 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': 1,
#   'Average Rating': 3.8,
#   'Reviews': 9,
#   'Downloads': '5,000+'},
#  130: {'Title': 'Secrets of beauty, youth and health',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '2.9 MB',
#   'Android Version': '2.3 and up',
#   'Current Version': 2,
#   'Average Rating': nan,
#   'Reviews': 77,
#   'Downloads': '10,000+'},
#  131: {'Title': 'Recipes and tips for losing weight',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '3.1 MB',
#   'Android Version': '3.0 and up',
#   'Current Version': 2,
#   'Average Rating': nan,
#   'Reviews': 35,
#   'Downloads': '10,000+'},
#  132: {'Title': 'Discover Color',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '6.4 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 1.1,
#   'Average Rating': 4.0,
#   'Reviews': 364,
#   'Downloads': '100,000+'},
#  133: {'Title': 'Eyeliner step by step 2018',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '3.2 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '1.2.13',
#   'Average Rating': 4.3,
#   'Reviews': 18,
#   'Downloads': '5,000+'},
#  134: {'Title': 'Dresses Ideas & Fashions +3000',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '8.2 MB',
#   'Android Version': '1.6 and up',
#   'Current Version': '1.0.2.0',
#   'Average Rating': 4.5,
#   'Reviews': 473,
#   'Downloads': '100,000+'},
#  135: {'Title': 'Lady adviser (beauty, health)',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '9.9 MB',
#   'Android Version': '3.0 and up',
#   'Current Version': 3,
#   'Average Rating': nan,
#   'Reviews': 30,
#   'Downloads': '10,000+'},
#  136: {'Title': 'Step By Step Hairstyles For Women',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '2.9 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '3.1.89',
#   'Average Rating': 4.1,
#   'Reviews': 66,
#   'Downloads': '10,000+'},
#  137: {'Title': 'Rainbow Camera',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '23 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': '2.2.0',
#   'Average Rating': 3.7,
#   'Reviews': 3871,
#   'Downloads': '1,000,000+'},
#  138: {'Title': 'Methods of teeth whitening',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '4.6 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 1,
#   'Average Rating': 4.7,
#   'Reviews': 257,
#   'Downloads': '50,000+'},
#  139: {'Title': 'Girls hairstyles 2018',
#   'Genre': 'BEAUTY',
#   'Type': 'Free',
#   'Size': '3.1 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '1.9.2',
#   'Average Rating': 4.2,
#   'Reviews': 62,
#   'Downloads': '10,000+'},
#  140: {'Title': 'Wattpad 📖 Free Books',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.6,
#   'Reviews': 2914724,
#   'Downloads': '100,000,000+'},
#  141: {'Title': 'E-Book Read - Read Book for free',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '4.9 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '1.3.2',
#   'Average Rating': 4.5,
#   'Reviews': 1857,
#   'Downloads': '50,000+'},
#  142: {'Title': 'Download free book with green book',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '9.5 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': 1.1,
#   'Average Rating': 4.6,
#   'Reviews': 4478,
#   'Downloads': '100,000+'},
#  143: {'Title': 'Wikipedia',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.4,
#   'Reviews': 577550,
#   'Downloads': '10,000,000+'},
#  144: {'Title': 'Amazon Kindle',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.2,
#   'Reviews': 814080,
#   'Downloads': '100,000,000+'},
#  145: {'Title': 'Cool Reader',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': '1.5 and up',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.5,
#   'Reviews': 246315,
#   'Downloads': '10,000,000+'},
#  146: {'Title': 'Dictionary - Merriam-Webster',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.5,
#   'Reviews': 454060,
#   'Downloads': '10,000,000+'},
#  147: {'Title': 'NOOK: Read eBooks & Magazines',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.5,
#   'Reviews': 155446,
#   'Downloads': '10,000,000+'},
#  148: {'Title': 'Free Panda Radio Music',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '4.2 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 2.1,
#   'Average Rating': 4.5,
#   'Reviews': 418,
#   'Downloads': '100,000+'},
#  149: {'Title': 'Book store',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '5.4 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': '3.2.1',
#   'Average Rating': 4.4,
#   'Reviews': 22486,
#   'Downloads': '1,000,000+'},
#  150: {'Title': 'FBReader: Favorite Book Reader',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.5,
#   'Reviews': 203130,
#   'Downloads': '10,000,000+'},
#  151: {'Title': 'English Grammar Complete Handbook',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '2.8 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': 1,
#   'Average Rating': 4.6,
#   'Reviews': 1435,
#   'Downloads': '500,000+'},
#  152: {'Title': 'Free Books - Spirit Fanfiction and Stories',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '5.0 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '2.0.075',
#   'Average Rating': 4.8,
#   'Reviews': 116507,
#   'Downloads': '1,000,000+'},
#  153: {'Title': 'Google Play Books',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 3.9,
#   'Reviews': 1433233,
#   'Downloads': '1,000,000,000+'},
#  154: {'Title': 'AlReader -any text book reader',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '5.9 MB',
#   'Android Version': '2.3 and up',
#   'Current Version': 1.91180527,
#   'Average Rating': 4.6,
#   'Reviews': 90468,
#   'Downloads': '5,000,000+'},
#  155: {'Title': 'Offline English Dictionary',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '13 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 1,
#   'Average Rating': 4.2,
#   'Reviews': 860,
#   'Downloads': '100,000+'},
#  156: {'Title': 'Oxford Dictionary of English : Free',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '7.1 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '9.1.363',
#   'Average Rating': 4.1,
#   'Reviews': 363934,
#   'Downloads': '10,000,000+'},
#  157: {'Title': 'Offline: English to Tagalog Dictionary',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '6.7 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '1.1.6',
#   'Average Rating': 4.7,
#   'Reviews': 967,
#   'Downloads': '500,000+'},
#  158: {'Title': 'Spanish English Translator',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.2,
#   'Reviews': 87873,
#   'Downloads': '10,000,000+'},
#  159: {'Title': 'FamilySearch Tree',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '17 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '2.3.18',
#   'Average Rating': 4.3,
#   'Reviews': 17506,
#   'Downloads': '1,000,000+'},
#  160: {'Title': 'Cloud of Books',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '19 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '2.2.5',
#   'Average Rating': 3.3,
#   'Reviews': 1862,
#   'Downloads': '1,000,000+'},
#  161: {'Title': 'Recipes of Prophetic Medicine for free',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '6.7 MB',
#   'Android Version': '2.3 and up',
#   'Current Version': 15,
#   'Average Rating': 4.6,
#   'Reviews': 2084,
#   'Downloads': '500,000+'},
#  162: {'Title': 'ReadEra – free ebook reader',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '21 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '18.05.31+530',
#   'Average Rating': 4.8,
#   'Reviews': 47303,
#   'Downloads': '1,000,000+'},
#  163: {'Title': 'NOOK App for NOOK Devices',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.7,
#   'Reviews': 19080,
#   'Downloads': '500,000+'},
#  164: {'Title': 'Anonymous caller detection',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '2.7 MB',
#   'Android Version': '2.3 and up',
#   'Current Version': 1,
#   'Average Rating': nan,
#   'Reviews': 161,
#   'Downloads': '10,000+'},
#  165: {'Title': 'Ebook Reader',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '37 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': '5.0.6',
#   'Average Rating': 4.1,
#   'Reviews': 85842,
#   'Downloads': '5,000,000+'},
#  166: {'Title': 'Litnet - E-books',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '15 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': '1.2.3',
#   'Average Rating': 4.6,
#   'Reviews': 7831,
#   'Downloads': '100,000+'},
#  167: {'Title': 'Read books online',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '23 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': 3.12,
#   'Average Rating': 4.1,
#   'Reviews': 91615,
#   'Downloads': '5,000,000+'},
#  168: {'Title': 'English to Urdu Dictionary',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '19 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 2,
#   'Average Rating': 4.6,
#   'Reviews': 4620,
#   'Downloads': '500,000+'},
#  169: {'Title': 'eBoox: book reader fb2 epub zip',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '23 MB',
#   'Android Version': '3.0 and up',
#   'Current Version': 1.28,
#   'Average Rating': 4.7,
#   'Reviews': 21336,
#   'Downloads': '1,000,000+'},
#  170: {'Title': 'English Persian Dictionary',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '73 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '6.0.8',
#   'Average Rating': 4.5,
#   'Reviews': 26875,
#   'Downloads': '500,000+'},
#  171: {'Title': 'Flybook',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '4.9 MB',
#   'Android Version': '2.1 and up',
#   'Current Version': '1.0.3',
#   'Average Rating': 3.9,
#   'Reviews': 1778,
#   'Downloads': '500,000+'},
#  172: {'Title': 'All Maths Formulas',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '6.8 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': 1.9,
#   'Average Rating': 4.4,
#   'Reviews': 2709,
#   'Downloads': '1,000,000+'},
#  173: {'Title': 'Ancestry',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.3,
#   'Reviews': 64513,
#   'Downloads': '5,000,000+'},
#  174: {'Title': 'HTC Help',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': '7.0 and up',
#   'Current Version': '9.00.950462',
#   'Average Rating': 4.2,
#   'Reviews': 8342,
#   'Downloads': '10,000,000+'},
#  175: {'Title': 'English translation from Bengali',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '2.9 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': 14,
#   'Average Rating': 4.5,
#   'Reviews': 527,
#   'Downloads': '100,000+'},
#  176: {'Title': 'Pdf Book Download - Read Pdf Book',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '3.5 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 6,
#   'Average Rating': 4.4,
#   'Reviews': 1322,
#   'Downloads': '100,000+'},
#  177: {'Title': 'Free Book Reader',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '4.0 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 3.05,
#   'Average Rating': 3.4,
#   'Reviews': 1680,
#   'Downloads': '100,000+'},
#  178: {'Title': 'eBoox new: Reader for fb2 epub zip books',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '21 MB',
#   'Android Version': '3.0 and up',
#   'Current Version': 2,
#   'Average Rating': 4.9,
#   'Reviews': 2739,
#   'Downloads': '50,000+'},
#  179: {'Title': 'Only 30 days in English, the guideline is guaranteed',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '2.3 MB',
#   'Android Version': '3.0 and up',
#   'Current Version': 1.5,
#   'Average Rating': 4.6,
#   'Reviews': 1065,
#   'Downloads': '500,000+'},
#  180: {'Title': 'Moon+ Reader',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.4,
#   'Reviews': 233757,
#   'Downloads': '10,000,000+'},
#  181: {'Title': "SH-02J Owner's Manual (Android 8.0)",
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '7.2 MB',
#   'Android Version': '6.0 and up',
#   'Current Version': 3,
#   'Average Rating': nan,
#   'Reviews': 2,
#   'Downloads': '50,000+'},
#  182: {'Title': 'English-Myanmar Dictionary',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '10 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': '2.5.3',
#   'Average Rating': 4.4,
#   'Reviews': 8788,
#   'Downloads': '1,000,000+'},
#  183: {'Title': 'Golden Dictionary (EN-AR)',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '6.1 MB',
#   'Android Version': '4.2 and up',
#   'Current Version': '7.0.4.6',
#   'Average Rating': 4.4,
#   'Reviews': 51269,
#   'Downloads': '1,000,000+'},
#  184: {'Title': 'All Language Translator Free',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '2.1 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': 1.15,
#   'Average Rating': 4.4,
#   'Reviews': 30105,
#   'Downloads': '1,000,000+'},
#  185: {'Title': 'Azpen eReader',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '42 MB',
#   'Android Version': '2.2 and up',
#   'Current Version': '3.1.7.9',
#   'Average Rating': 3.5,
#   'Reviews': 156,
#   'Downloads': '500,000+'},
#  186: {'Title': 'URBANO V 02 instruction manual',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '7.3 MB',
#   'Android Version': '5.1 and up',
#   'Current Version': 1.1,
#   'Average Rating': nan,
#   'Reviews': 114,
#   'Downloads': '100,000+'},
#  187: {'Title': 'English Dictionary - Offline',
#   'Genre': 'BOOKS_AND_REFERENCE',
#   'Type': 'Free',
#   'Size': '30 MB',
#   'Android Version': '4.2 and up',
#   'Current Version': '3.9.1',
#   'Average Rating': 4.4,
#   'Reviews': 341157,
#   'Downloads': '10,000,000+'},
#  188: {'Title': 'Visual Voicemail by MetroPCS',
#   'Genre': 'BUSINESS',
#   'Type': 'Free',
#   'Size': 'Varies with device',
# ...
#   'Size': 'Varies with device',
#   'Android Version': '5.0 and up',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.0,
#   'Reviews': 319691,
#   'Downloads': '10,000,000+'},
#  940: {'Title': 'FOX NOW - On Demand & Live TV',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': '4.4 and up',
#   'Current Version': 'Varies with device',
#   'Average Rating': 3.9,
#   'Reviews': 60841,
#   'Downloads': '5,000,000+'},
#  941: {'Title': 'The CW',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '21 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': 2.17,
#   'Average Rating': 4.4,
#   'Reviews': 288150,
#   'Downloads': '5,000,000+'},
#  942: {'Title': 'CW Seed',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '13 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': 1.16,
#   'Average Rating': 4.5,
#   'Reviews': 16372,
#   'Downloads': '500,000+'},
#  943: {'Title': 'The NBC App - Watch Live TV and Full Episodes',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '17 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '4.18.1',
#   'Average Rating': 4.1,
#   'Reviews': 58028,
#   'Downloads': '5,000,000+'},
#  944: {'Title': 'HISTORY: Watch TV Show Full Episodes & Specials',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '20 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '3.1.4',
#   'Average Rating': 4.1,
#   'Reviews': 33387,
#   'Downloads': '1,000,000+'},
#  945: {'Title': 'HBO NOW: Stream TV & Movies',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 3.9,
#   'Reviews': 61201,
#   'Downloads': '10,000,000+'},
#  946: {'Title': 'WWE',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '20 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '3.17.2',
#   'Average Rating': 4.5,
#   'Reviews': 736864,
#   'Downloads': '10,000,000+'},
#  947: {'Title': 'A&E - Watch Full Episodes of TV Shows',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '19 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '3.1.4',
#   'Average Rating': 4.0,
#   'Reviews': 29706,
#   'Downloads': '1,000,000+'},
#  948: {'Title': 'VH1',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '17 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '11.45.0',
#   'Average Rating': 4.1,
#   'Reviews': 27424,
#   'Downloads': '1,000,000+'},
#  949: {'Title': 'Universal Kids',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '21 MB',
#   'Android Version': '3.3.1.41',
#   'Current Version': 'May 24, 2018',
#   'Average Rating': 3.6,
#   'Reviews': 1968,
#   'Downloads': '500,000+'},
#  950: {'Title': 'MTV',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '15 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '11.45.0',
#   'Average Rating': 3.8,
#   'Reviews': 35279,
#   'Downloads': '1,000,000+'},
#  951: {'Title': 'Lifetime - Watch Full Episodes & Original Movies',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '19 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '3.1.4',
#   'Average Rating': 4.0,
#   'Reviews': 35931,
#   'Downloads': '1,000,000+'},
#  952: {'Title': 'BET NOW - Watch Shows',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '19 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '11.45.0',
#   'Average Rating': 4.2,
#   'Reviews': 14807,
#   'Downloads': '1,000,000+'},
#  953: {'Title': 'LEGO® TV',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '7.2 MB',
#   'Android Version': '4.0.2',
#   'Current Version': 'August 4, 2018',
#   'Average Rating': 3.7,
#   'Reviews': 17247,
#   'Downloads': '1,000,000+'},
#  954: {'Title': 'HBO GO: Stream with TV Package',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '32 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '16.0.0.437',
#   'Average Rating': 3.8,
#   'Reviews': 87723,
#   'Downloads': '10,000,000+'},
#  955: {'Title': 'Showtime Anytime',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 3.7,
#   'Reviews': 18523,
#   'Downloads': '1,000,000+'},
#  956: {'Title': 'PlayKids - Educational cartoons and games for kids',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'July 30, 2018',
#   'Average Rating': 4.1,
#   'Reviews': 182103,
#   'Downloads': '10,000,000+'},
#  957: {'Title': 'FOX',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '44 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '6.6.1',
#   'Average Rating': 3.7,
#   'Reviews': 197774,
#   'Downloads': '10,000,000+'},
#  958: {'Title': 'Telemundo Now',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '19 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '3.3.1.42',
#   'Average Rating': 3.9,
#   'Reviews': 8674,
#   'Downloads': '1,000,000+'},
#  959: {'Title': 'Netflix',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.4,
#   'Reviews': 5456708,
#   'Downloads': '100,000,000+'},
#  960: {'Title': 'Tubi TV - Free Movies & TV',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '11 MB',
#   'Android Version': '4.1 and up',
#   'Current Version': '2.13.5',
#   'Average Rating': 4.3,
#   'Reviews': 296771,
#   'Downloads': '10,000,000+'},
#  961: {'Title': 'Vudu Movies & TV',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 3.9,
#   'Reviews': 58082,
#   'Downloads': '10,000,000+'},
#  962: {'Title': 'Crackle - Free TV & Movies',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 3.7,
#   'Reviews': 388089,
#   'Downloads': '10,000,000+'},
#  963: {'Title': 'Crunchyroll - Everything Anime',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 3.7,
#   'Reviews': 310066,
#   'Downloads': '10,000,000+'},
#  964: {'Title': 'Nick',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '25 MB',
#   'Android Version': '2.0.8',
#   'Current Version': 'January 24, 2018',
#   'Average Rating': 4.2,
#   'Reviews': 123279,
#   'Downloads': '10,000,000+'},
#  965: {'Title': 'STARZ',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.3,
#   'Reviews': 88185,
#   'Downloads': '10,000,000+'},
#  966: {'Title': 'Hulu: Stream TV, Movies & more',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': '5.0 and up',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.0,
#   'Reviews': 319691,
#   'Downloads': '10,000,000+'},
#  967: {'Title': 'Food Network',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.1,
#   'Reviews': 7813,
#   'Downloads': '500,000+'},
#  968: {'Title': 'FOX NOW - On Demand & Live TV',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': '4.4 and up',
#   'Current Version': 'Varies with device',
#   'Average Rating': 3.9,
#   'Reviews': 60841,
#   'Downloads': '5,000,000+'},
#  969: {'Title': 'Movies by Flixster, with Rotten Tomatoes',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '16 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '9.1.4',
#   'Average Rating': 4.5,
#   'Reviews': 653008,
#   'Downloads': '10,000,000+'},
#  970: {'Title': 'Yidio: TV Show & Movie Guide',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 3.9,
#   'Reviews': 27424,
#   'Downloads': '1,000,000+'},
#  971: {'Title': 'HISTORY: Watch TV Show Full Episodes & Specials',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '20 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '3.1.4',
#   'Average Rating': 4.1,
#   'Reviews': 33387,
#   'Downloads': '1,000,000+'},
#  972: {'Title': 'Viki: Asian TV Dramas & Movies',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.3,
#   'Reviews': 407719,
#   'Downloads': '10,000,000+'},
#  973: {'Title': 'The CW',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '21 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': 2.17,
#   'Average Rating': 4.4,
#   'Reviews': 288150,
#   'Downloads': '5,000,000+'},
#  974: {'Title': 'Redbox',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '30 MB',
#   'Android Version': '5.0 and up',
#   'Current Version': '7.5.0',
#   'Average Rating': 4.1,
#   'Reviews': 115033,
#   'Downloads': '10,000,000+'},
#  975: {'Title': 'Univision NOW - Live TV and On Demand',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 8.0626,
#   'Average Rating': 4.0,
#   'Reviews': 22997,
#   'Downloads': '1,000,000+'},
#  976: {'Title': 'HBO NOW: Stream TV & Movies',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 3.9,
#   'Reviews': 61201,
#   'Downloads': '10,000,000+'},
#  977: {'Title': 'Tribeca Shortlist - Handpicked Movies',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '57 MB',
#   'Android Version': '4.3 and up',
#   'Current Version': '4.003.1',
#   'Average Rating': 3.9,
#   'Reviews': 801,
#   'Downloads': '100,000+'},
#  978: {'Title': 'A&E - Watch Full Episodes of TV Shows',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '19 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '3.1.4',
#   'Average Rating': 4.0,
#   'Reviews': 29706,
#   'Downloads': '1,000,000+'},
#  979: {'Title': 'VH1',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '17 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '11.45.0',
#   'Average Rating': 4.1,
#   'Reviews': 27424,
#   'Downloads': '1,000,000+'},
#  980: {'Title': 'SHOWTIME',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.2,
#   'Reviews': 12398,
#   'Downloads': '1,000,000+'},
#  981: {'Title': 'MTV',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '15 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '11.45.0',
#   'Average Rating': 3.8,
#   'Reviews': 35279,
#   'Downloads': '1,000,000+'},
#  982: {'Title': 'Lifetime - Watch Full Episodes & Original Movies',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '19 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '3.1.4',
#   'Average Rating': 4.0,
#   'Reviews': 35931,
#   'Downloads': '1,000,000+'},
#  983: {'Title': 'Comedy Central',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '19 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '11.45.0',
#   'Average Rating': 3.9,
#   'Reviews': 22378,
#   'Downloads': '1,000,000+'},
#  984: {'Title': 'BET NOW - Watch Shows',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '19 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '11.45.0',
#   'Average Rating': 4.2,
#   'Reviews': 14807,
#   'Downloads': '1,000,000+'},
#  985: {'Title': 'FOX',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '44 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '6.6.1',
#   'Average Rating': 3.7,
#   'Reviews': 197774,
#   'Downloads': '10,000,000+'},
#  986: {'Title': 'Telemundo Now',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '19 MB',
#   'Android Version': '4.4 and up',
#   'Current Version': '3.3.1.42',
#   'Average Rating': 3.9,
#   'Reviews': 8674,
#   'Downloads': '1,000,000+'},
#  987: {'Title': 'Nick Jr. - Shows & Games',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '35 MB',
#   'Android Version': '1.0.20',
#   'Current Version': 'January 23, 2018',
#   'Average Rating': 4.2,
#   'Reviews': 8968,
#   'Downloads': '1,000,000+'},
#  988: {'Title': 'Sticker Market: Emoji keyboard',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '44 MB',
#   'Android Version': '4.2 and up',
#   'Current Version': '1.2.3',
#   'Average Rating': 4.3,
#   'Reviews': 303,
#   'Downloads': '10,000+'},
#  989: {'Title': 'Viki: Asian TV Dramas & Movies',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.3,
#   'Reviews': 407719,
#   'Downloads': '10,000,000+'},
#  990: {'Title': 'Kidjo TV Kids Have Fun & Learn',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'August 1, 2018',
#   'Average Rating': 4.6,
#   'Reviews': 732,
#   'Downloads': '100,000+'},
#  991: {'Title': 'Laugh Out Loud by Kevin Hart',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '20 MB',
#   'Android Version': '6.0 and up',
#   'Current Version': '1.6.1',
#   'Average Rating': 4.3,
#   'Reviews': 1856,
#   'Downloads': '100,000+'},
#  992: {'Title': 'ColorFul - Adult Coloring Book',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '19 MB',
#   'Android Version': '4.0.3 and up',
#   'Current Version': '1.0.64',
#   'Average Rating': 4.6,
#   'Reviews': 50725,
#   'Downloads': '5,000,000+'},
#  993: {'Title': 'Nick',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '25 MB',
#   'Android Version': '2.0.8',
#   'Current Version': 'January 24, 2018',
#   'Average Rating': 4.2,
#   'Reviews': 123279,
#   'Downloads': '10,000,000+'},
#  994: {'Title': 'Fandango Movies - Times + Tickets',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.6,
#   'Reviews': 243747,
#   'Downloads': '10,000,000+'},
#  995: {'Title': 'Hamilton — The Official App',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '43 MB',
#   'Android Version': '5.0 and up',
#   'Current Version': '2.3.2',
#   'Average Rating': 4.5,
#   'Reviews': 1575,
#   'Downloads': '100,000+'},
#  996: {'Title': 'My Talking Pet',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Paid',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 4.6,
#   'Reviews': 6238,
#   'Downloads': '100,000+'},
#  997: {'Title': 'Funny Pics',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': 'Varies with device',
#   'Android Version': 'Varies with device',
#   'Current Version': 'Varies with device',
#   'Average Rating': 3.9,
#   'Reviews': 9941,
#   'Downloads': '1,000,000+'},
#  998: {'Title': 'Funny Quotes Free',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '3.6 MB',
#   'Android Version': '4.0 and up',
#   'Current Version': 8.1,
#   'Average Rating': 4.2,
#   'Reviews': 23666,
#   'Downloads': '1,000,000+'},
#  999: {'Title': 'LOL Pics (Funny Pictures)',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '7.7 MB',
#   'Android Version': '2.3.3 and up',
#   'Current Version': 4,
#   'Average Rating': 4.4,
#   'Reviews': 67554,
#   'Downloads': '1,000,000+'},
#  1000: {'Title': 'Meme Creator',
#   'Genre': 'ENTERTAINMENT',
#   'Type': 'Free',
#   'Size': '44 MB',
#   'Android Version': '2.3 and up',
#   'Current Version': '7.2.3',
#   'Average Rating': 4.2,
#   'Reviews': 38769,
#   'Downloads': '1,000,000+'},
#  ...}

# %% [markdown]
# ## Delete Variables
# Delete the variables which are no longer in use while holding large amounts of data

# %%
del App_id
del App_Title
del App_Genre
del App_Type
del App_Size
del App_Android
del App_Current
del App_Rating
del App_Reviews
del App_Downloads

# %% [markdown]
# ### Since the keys are unique and non redundant hence there is no need to group the data

# %% [markdown]
# ## Convert into JSON

# %%
import json
print("[INFO] Writing movie Data into the disk...")
with open('Datastore/dataFinal.json', 'w') as fp:
    json.dump(appDict, fp, sort_keys=True, indent=4)
print("[INFO] Writing Global Secondary Index Data into the disk...")
with open('Datastore/dataFinal_GIS.json', 'w') as fp:
    json.dump(global_secondaryIndex, fp, sort_keys=True, indent=4)

print("Done")
# Out:
# [INFO] Writing movie Data into the disk...
# [INFO] Writing Global Secondary Index Data into the disk...
# Done

# %% [markdown]
# **Now our data is prepared and ready to handle high inflow of requests**
